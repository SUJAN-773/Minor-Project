# %%
import cv2

# %%
img = cv2.imread("C:/Users/asus/Pictures/Camera Roll/WIN_20221125_20_59_47_Pro.jpg")

# %%
img.shape
# Out:
# (720, 1280, 3)

# %%
img[0]
# Out:
# array([[ 11,  56,  23],
#        [ 12,  55,  22],
#        [ 12,  53,  22],
#        ...,
#        [144, 165, 143],
#        [143, 165, 141],
#        [143, 165, 141]], dtype=uint8)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
while True:
    cv2.imshow('result', img)
    if cv2.waitKey(2) == 27:
        break
cv2.destroyAllWindows()

# %%
haar_data=cv2.CascadeClassifier('data.xml')

# %%
haar_data.detectMultiScale(img)

# %%
cv2.rectangle(img,(x,y),(w,h),(b,g,r),border_thickness)

# %%
# while True:
#     faces = haar_data.detectMultiScale(img)
#     for x,y,w,h in faces:
#         cv2.rectangle(img, (x,y), (w+x, y+h), (255, 0, 255), 4)
#     cv2.imshow('result', img)
#     if cv2.waitKey(2) == 27:
#         break
# cv2.destroyAllWindows()

# %%
capture = cv2.VideoCapture(0)
while True:
    flag, img = capture.read()
    if flag:
        faces = haar_data.detectMultiScale(img)
        for x,y,w,h in faces:
            cv2.rectangle(img, (x,y), (w+x, y+h), (255, 0, 255), 4)
        cv2.imshow('result', img)
        if cv2.waitKey(2) == 27:
            break
capture.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15256\167086222.py in <module>
#       3     flag, img = capture.read()
#       4     if flag:
# ----> 5         faces = haar_data.detectMultiScale(img)
#       6         for x,y,w,h in faces:
#       7             cv2.rectangle(img, (x,y), (w+x, y+h), (255, 0, 255), 4)
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\objdetect\src\cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'cv::CascadeClassifier::detectMultiScale'

# %%
import numpy as np

# %%
x=np.array([3,2,54,6])

# %%
x
# Out:
# array([ 3,  2, 54,  6])

# %%
x[0:2]
# Out:
# array([3, 2])

# %%
x=np.array([[3,4,54,67,8,8],[1,2,2,4,5],[4,5,3,5,6,7],[1,2,3,34,6,8]])
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_15256\2704111968.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   x=np.array([[3,4,54,67,8,8],[1,2,2,4,5],[4,5,3,5,6,7],[1,2,3,34,6,8]])

# %%
x
# Out:
# array([list([3, 4, 54, 67, 8, 8]), list([1, 2, 2, 4, 5]),
#        list([4, 5, 3, 5, 6, 7]), list([1, 2, 3, 34, 6, 8])], dtype=object)
